# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.shape
# Out:
# (3496, 27)

# %%
matches["team"].value_counts()
# Out:
# Manchester City             190
# Leicester City              190
# Burnley                     190
# Everton                     190
# Liverpool                   190
# Southampton                 190
# Chelsea                     190
# Manchester United           190
# Tottenham Hotspur           190
# Arsenal                     190
# Crystal Palace              152
# West Ham United             152
# Newcastle United            152
# Wolverhampton Wanderers     152
# Brighton and Hove Albion    152
# Watford                     114
# Aston Villa                  76
# Leeds United                 76
# Fulham                       76
# West Bromwich Albion         76
# Sheffield United             76
# Bournemouth                  76
# Huddersfield Town            76
# Brentford                    38
# Norwich City                 38
# Cardiff City                 38
# Swansea City                 38
# Stoke City                   38
# Name: team, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1     92
# Matchweek 29    92
# Matchweek 22    92
# Matchweek 23    92
# Matchweek 24    92
# Matchweek 25    92
# Matchweek 26    92
# Matchweek 27    92
# Matchweek 28    92
# Matchweek 31    92
# Matchweek 2     92
# Matchweek 32    92
# Matchweek 30    92
# Matchweek 34    92
# Matchweek 35    92
# Matchweek 36    92
# Matchweek 33    92
# Matchweek 37    92
# Matchweek 21    92
# Matchweek 20    92
# Matchweek 19    92
# Matchweek 18    92
# Matchweek 3     92
# Matchweek 4     92
# Matchweek 5     92
# Matchweek 6     92
# Matchweek 7     92
# Matchweek 8     92
# Matchweek 9     92
# Matchweek 10    92
# Matchweek 11    92
# Matchweek 12    92
# Matchweek 13    92
# Matchweek 14    92
# Matchweek 15    92
# Matchweek 16    92
# Matchweek 17    92
# Matchweek 38    92
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf                int64
# ga                int64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time         round  day venue result  gf  ga        opponent  \
# 1  2021-08-15  16:30   Matchweek 1  Sun  Away      L   0   1       Tottenham
# 2  2021-08-21  15:00   Matchweek 2  Sat  Home      W   5   0    Norwich City
# 3  2021-08-28  12:30   Matchweek 3  Sat  Home      W   5   0         Arsenal
# 4  2021-09-11  15:00   Matchweek 4  Sat  Away      W   1   0  Leicester City
# 6  2021-09-18  15:00   Matchweek 5  Sat  Home      D   0   0     Southampton
# ..        ...    ...           ...  ...   ...    ...  ..  ..             ...
# 38 2018-04-15  16:00  Matchweek 34  Sun  Away      W   1   0  Manchester Utd
# 39 2018-04-21  12:30  Matchweek 35  Sat  Home      D   2   2       Liverpool
# 40 2018-04-28  15:00  Matchweek 36  Sat  Away      W   1   0   Newcastle Utd
# 41 2018-05-05  15:00  Matchweek 37  Sat  Home      W   1   0       Tottenham
# 42 2018-05-13  15:00  Matchweek 38  Sun  Away      L   0   2  Crystal Palace
#
#      xg  ...  match report    sh   sot  dist   fk   pk pkatt  season  \
# 1   1.9  ...  Match Report  18.0   4.0  16.9  1.0  0.0   0.0    2022
# 2   2.7  ...  Match Report  16.0   4.0  17.3  1.0  0.0   0.0    2022
# 3   3.8  ...  Match Report  25.0  10.0  14.3  0.0  0.0   0.0    2022
# 4   2.9  ...  Match Report  25.0   8.0  14.0  0.0  0.0   0.0    2022
# 6   1.1  ...  Match Report  16.0   1.0  15.7  1.0  0.0   0.0    2022
# ..  ...  ...           ...   ...   ...   ...  ...  ...   ...     ...
# 38  0.8  ...  Match Report  10.0   4.0  18.8  0.0  0.0   0.0    2021
# 39  1.4  ...  Match Report  12.0   5.0  18.1  0.0  0.0   0.0    2021
# 40  0.8  ...  Match Report   9.0   2.0  18.5  0.0  0.0   0.0    2021
# 41  1.4  ...  Match Report  10.0   1.0  10.4  0.0  0.0   0.0    2021
# 42  0.3  ...  Match Report   7.0   1.0  24.5  1.0  0.0   0.0    2021
#
#                     team  target
# 1        Manchester City       0
# 2        Manchester City       1
# 3        Manchester City       1
# 4        Manchester City       1
# 6        Manchester City       0
# ..                   ...     ...
# 38  West Bromwich Albion       1
# 39  West Bromwich Albion       0
# 40  West Bromwich Albion       1
# 41  West Bromwich Albion       1
# 42  West Bromwich Albion       0
#
# [3496 rows x 26 columns]

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches
# Out:
#          date   time         round  day venue result  gf  ga        opponent  \
# 1  2021-08-15  16:30   Matchweek 1  Sun  Away      L   0   1       Tottenham
# 2  2021-08-21  15:00   Matchweek 2  Sat  Home      W   5   0    Norwich City
# 3  2021-08-28  12:30   Matchweek 3  Sat  Home      W   5   0         Arsenal
# 4  2021-09-11  15:00   Matchweek 4  Sat  Away      W   1   0  Leicester City
# 6  2021-09-18  15:00   Matchweek 5  Sat  Home      D   0   0     Southampton
# ..        ...    ...           ...  ...   ...    ...  ..  ..             ...
# 38 2018-04-15  16:00  Matchweek 34  Sun  Away      W   1   0  Manchester Utd
# 39 2018-04-21  12:30  Matchweek 35  Sat  Home      D   2   2       Liverpool
# 40 2018-04-28  15:00  Matchweek 36  Sat  Away      W   1   0   Newcastle Utd
# 41 2018-05-05  15:00  Matchweek 37  Sat  Home      W   1   0       Tottenham
# 42 2018-05-13  15:00  Matchweek 38  Sun  Away      L   0   2  Crystal Palace
#
#      xg  ...   fk   pk  pkatt season                  team target venue_code  \
# 1   1.9  ...  1.0  0.0    0.0   2022       Manchester City      0          0
# 2   2.7  ...  1.0  0.0    0.0   2022       Manchester City      1          1
# 3   3.8  ...  0.0  0.0    0.0   2022       Manchester City      1          1
# 4   2.9  ...  0.0  0.0    0.0   2022       Manchester City      1          0
# 6   1.1  ...  1.0  0.0    0.0   2022       Manchester City      0          1
# ..  ...  ...  ...  ...    ...    ...                   ...    ...        ...
# 38  0.8  ...  0.0  0.0    0.0   2021  West Bromwich Albion      1          0
# 39  1.4  ...  0.0  0.0    0.0   2021  West Bromwich Albion      0          1
# 40  0.8  ...  0.0  0.0    0.0   2021  West Bromwich Albion      1          0
# 41  1.4  ...  0.0  0.0    0.0   2021  West Bromwich Albion      1          1
# 42  0.3  ...  1.0  0.0    0.0   2021  West Bromwich Albion      0          0
#
#     opp_code  hour  day_code
# 1         23    16         6
# 2         18    15         5
# 3          0    12         5
# 4         13    15         5
# 6         20    15         5
# ..       ...   ...       ...
# 38        16    16         6
# 39        14    12         5
# 40        17    15         5
# 41        23    15         5
# 42         8    15         6
#
# [3496 rows x 30 columns]

# %%
#from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
#rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
xgb=XGBClassifier(n_estimators=50 , max_depth=4, learning_rate=0.08,colsample_bytree=0.2,
                   random_state=12,subsample=0.8)

# %%
train = matches[matches["date"] < '2022-01-01']

# %%
test = matches[matches["date"] > '2022-01-01']

# %%
test
# Out:
#          date   time         round  day venue result  gf  ga        opponent  \
# 31 2022-01-15  12:30  Matchweek 22  Sat  Home      W   1   0         Chelsea
# 32 2022-01-22  17:30  Matchweek 23  Sat  Away      D   1   1     Southampton
# 34 2022-02-09  19:45  Matchweek 24  Wed  Home      W   2   0       Brentford
# 35 2022-02-12  17:30  Matchweek 25  Sat  Away      W   4   0    Norwich City
# 37 2022-02-19  17:30  Matchweek 26  Sat  Home      L   2   3       Tottenham
# ..        ...    ...           ...  ...   ...    ...  ..  ..             ...
# 38 2022-04-30  15:00  Matchweek 35  Sat  Away      L   0   2     Aston Villa
# 39 2022-05-08  14:00  Matchweek 36  Sun  Home      L   0   4        West Ham
# 40 2022-05-11  19:45  Matchweek 21  Wed  Away      L   0   3  Leicester City
# 41 2022-05-15  14:00  Matchweek 37  Sun  Away      D   1   1          Wolves
# 42 2022-05-22  16:00  Matchweek 38  Sun  Home      L   0   5       Tottenham
#
#      xg  ...   fk   pk  pkatt season             team target venue_code  \
# 31  0.7  ...  1.0  0.0    0.0   2022  Manchester City      1          1
# 32  1.6  ...  0.0  0.0    0.0   2022  Manchester City      0          0
# 34  2.0  ...  0.0  1.0    1.0   2022  Manchester City      1          1
# 35  4.6  ...  0.0  0.0    1.0   2022  Manchester City      1          0
# 37  2.1  ...  0.0  1.0    1.0   2022  Manchester City      0          1
# ..  ...  ...  ...  ...    ...    ...              ...    ...        ...
# 38  0.6  ...  0.0  0.0    0.0   2022     Norwich City      0          0
# 39  0.7  ...  1.0  0.0    0.0   2022     Norwich City      0          1
# 40  1.2  ...  0.0  0.0    0.0   2022     Norwich City      0          0
# 41  1.3  ...  0.0  0.0    0.0   2022     Norwich City      0          0
# 42  0.3  ...  0.0  0.0    0.0   2022     Norwich City      0          1
#
#     opp_code  hour  day_code
# 31         7    12         5
# 32        20    17         5
# 34         3    19         2
# 35        18    17         5
# 37        23    17         5
# ..       ...   ...       ...
# 38         1    15         5
# 39        26    14         6
# 40        13    19         2
# 41        27    14         6
# 42        23    16         6
#
# [388 rows x 30 columns]

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.615979381443299

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0   1
# actual
# 0          225   8
# 1          141  14

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.6363636363636364

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time         round  day venue result  gf  ga        opponent  \
# 3  2017-09-09  12:30   Matchweek 4  Sat  Home      W   5   0       Liverpool
# 5  2017-09-16  15:00   Matchweek 5  Sat  Away      W   6   0         Watford
# 7  2017-09-23  15:00   Matchweek 6  Sat  Home      W   5   0  Crystal Palace
# 9  2017-09-30  17:30   Matchweek 7  Sat  Away      W   1   0         Chelsea
# 10 2017-10-14  15:00   Matchweek 8  Sat  Home      W   7   2      Stoke City
# ..        ...    ...           ...  ...   ...    ...  ..  ..             ...
# 52 2022-04-30  17:30  Matchweek 35  Sat  Away      W   4   0    Leeds United
# 54 2022-05-08  16:30  Matchweek 36  Sun  Home      W   5   0   Newcastle Utd
# 55 2022-05-11  20:15  Matchweek 33  Wed  Away      W   5   1          Wolves
# 56 2022-05-15  14:00  Matchweek 37  Sun  Away      D   2   2        West Ham
# 57 2022-05-22  16:00  Matchweek 38  Sun  Home      W   3   2     Aston Villa
#
#      xg  ...  hour  day_code  gf_rolling ga_rolling sh_rolling sot_rolling  \
# 3   2.7  ...    12         5    1.666667   0.666667  17.333333    6.000000
# 5   3.6  ...    15         5    2.666667   0.666667  17.000000    8.000000
# 7   4.4  ...    15         5    4.333333   0.333333  19.333333    9.000000
# 9   1.1  ...    17         5    5.333333   0.000000  21.666667    9.333333
# 10  3.9  ...    15         5    4.000000   0.000000  23.000000    7.666667
# ..  ...  ...   ...       ...         ...        ...        ...         ...
# 52  2.7  ...    17         5    3.333333   1.000000  16.000000    5.333333
# 54  3.1  ...    16         6    4.000000   0.333333  18.666667    6.000000
# 55  3.1  ...    20         2    4.666667   0.333333  20.000000    7.333333
# 56  2.5  ...    14         6    4.666667   0.333333  18.333333    6.666667
# 57  2.9  ...    16         6    4.000000   1.000000  22.000000    7.000000
#
#    dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# 3     18.233333    1.333333    0.000000       0.000000
# 5     16.500000    0.666667    0.000000       0.000000
# 7     15.966667    0.333333    0.333333       0.333333
# 9     14.866667    0.000000    0.333333       0.333333
# 10    15.866667    0.333333    0.333333       0.333333
# ..          ...         ...         ...            ...
# 52    16.700000    0.333333    0.333333       0.333333
# 54    16.333333    0.000000    0.333333       0.333333
# 55    15.166667    0.333333    0.333333       0.333333
# 56    14.933333    0.333333    0.000000       0.000000
# 57    15.700000    1.000000    0.000000       0.333333
#
# [187 rows x 38 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time         round  day venue result  \
# team
# Arsenal                 4  2017-09-09  15:00   Matchweek 4  Sat  Home      W
#                         6  2017-09-17  13:30   Matchweek 5  Sun  Away      D
#                         8  2017-09-25  20:00   Matchweek 6  Mon  Home      W
#                         10 2017-10-01  12:00   Matchweek 7  Sun  Home      W
#                         11 2017-10-14  17:30   Matchweek 8  Sat  Away      L
# ...                               ...    ...           ...  ...   ...    ...
# Wolverhampton Wanderers 37 2022-04-30  15:00  Matchweek 35  Sat  Home      L
#                         38 2022-05-07  15:00  Matchweek 36  Sat  Away      D
#                         39 2022-05-11  20:15  Matchweek 33  Wed  Home      L
#                         40 2022-05-15  14:00  Matchweek 37  Sun  Home      D
#                         41 2022-05-22  16:00  Matchweek 38  Sun  Away      L
#
#                             gf  ga         opponent   xg  ...  hour  day_code  \
# team                                                      ...
# Arsenal                 4    3   0      Bournemouth  2.0  ...    15         5
#                         6    0   0          Chelsea  1.4  ...    13         6
#                         8    2   0        West Brom  2.4  ...    20         0
#                         10   2   0         Brighton  3.0  ...    12         6
#                         11   1   2          Watford  1.1  ...    17         5
# ...                         ..  ..              ...  ...  ...   ...       ...
# Wolverhampton Wanderers 37   0   3         Brighton  0.6  ...    15         5
#                         38   2   2          Chelsea  2.1  ...    15         5
#                         39   1   5  Manchester City  0.5  ...    20         2
#                         40   1   1     Norwich City  0.9  ...    14         6
#                         41   1   3        Liverpool  1.1  ...    16         6
#
#                             gf_rolling ga_rolling sh_rolling sot_rolling  \
# team
# Arsenal                 4     1.333333   2.666667  18.000000    5.666667
#                         6     1.000000   1.666667  14.666667    5.333333
#                         8     1.000000   1.333333  12.000000    3.666667
#                         10    1.666667   0.000000  14.333333    5.333333
#                         11    1.333333   0.000000  17.333333    5.000000
# ...                                ...        ...        ...         ...
# Wolverhampton Wanderers 37    0.666667   1.000000   8.666667    3.333333
#                         38    0.000000   1.666667   8.666667    2.333333
#                         39    0.666667   2.000000  11.666667    3.000000
#                         40    1.000000   3.333333  10.666667    2.666667
#                         41    1.333333   2.666667  12.666667    3.666667
#
#                            dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# team
# Arsenal                 4     17.600000    0.000000    0.000000       0.000000
#                         6     16.233333    0.333333    0.000000       0.000000
#                         8     16.033333    0.333333    0.000000       0.000000
#                         10    16.800000    1.333333    0.333333       0.333333
#                         11    17.833333    1.666667    0.333333       0.333333
# ...                                 ...         ...         ...            ...
# Wolverhampton Wanderers 37    16.966667    0.000000    0.000000       0.000000
#                         38    18.233333    0.333333    0.000000       0.000000
#                         39    17.133333    0.333333    0.000000       0.000000
#                         40    16.400000    0.333333    0.000000       0.000000
#                         41    17.033333    0.666667    0.000000       0.000000
#
# [3403 rows x 38 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time         round  day venue result  gf  ga         opponent  \
# 4  2017-09-09  15:00   Matchweek 4  Sat  Home      W   3   0      Bournemouth
# 6  2017-09-17  13:30   Matchweek 5  Sun  Away      D   0   0          Chelsea
# 8  2017-09-25  20:00   Matchweek 6  Mon  Home      W   2   0        West Brom
# 10 2017-10-01  12:00   Matchweek 7  Sun  Home      W   2   0         Brighton
# 11 2017-10-14  17:30   Matchweek 8  Sat  Away      L   1   2          Watford
# ..        ...    ...           ...  ...   ...    ...  ..  ..              ...
# 37 2022-04-30  15:00  Matchweek 35  Sat  Home      L   0   3         Brighton
# 38 2022-05-07  15:00  Matchweek 36  Sat  Away      D   2   2          Chelsea
# 39 2022-05-11  20:15  Matchweek 33  Wed  Home      L   1   5  Manchester City
# 40 2022-05-15  14:00  Matchweek 37  Sun  Home      D   1   1     Norwich City
# 41 2022-05-22  16:00  Matchweek 38  Sun  Away      L   1   3        Liverpool
#
#      xg  ...  hour  day_code  gf_rolling ga_rolling sh_rolling sot_rolling  \
# 4   2.0  ...    15         5    1.333333   2.666667  18.000000    5.666667
# 6   1.4  ...    13         6    1.000000   1.666667  14.666667    5.333333
# 8   2.4  ...    20         0    1.000000   1.333333  12.000000    3.666667
# 10  3.0  ...    12         6    1.666667   0.000000  14.333333    5.333333
# 11  1.1  ...    17         5    1.333333   0.000000  17.333333    5.000000
# ..  ...  ...   ...       ...         ...        ...        ...         ...
# 37  0.6  ...    15         5    0.666667   1.000000   8.666667    3.333333
# 38  2.1  ...    15         5    0.000000   1.666667   8.666667    2.333333
# 39  0.5  ...    20         2    0.666667   2.000000  11.666667    3.000000
# 40  0.9  ...    14         6    1.000000   3.333333  10.666667    2.666667
# 41  1.1  ...    16         6    1.333333   2.666667  12.666667    3.666667
#
#    dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# 4     17.600000    0.000000    0.000000       0.000000
# 6     16.233333    0.333333    0.000000       0.000000
# 8     16.033333    0.333333    0.000000       0.000000
# 10    16.800000    1.333333    0.333333       0.333333
# 11    17.833333    1.666667    0.333333       0.333333
# ..          ...         ...         ...            ...
# 37    16.966667    0.000000    0.000000       0.000000
# 38    18.233333    0.333333    0.000000       0.000000
# 39    17.133333    0.333333    0.000000       0.000000
# 40    16.400000    0.333333    0.000000       0.000000
# 41    17.033333    0.666667    0.000000       0.000000
#
# [3403 rows x 38 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = xgb.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)

# %%
error
# Out:
# 0.5945945945945946

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined[combined["actual"] == combined["predicted"]]["team"].value_counts()
# Out:
# Watford                     18
# Norwich City                16
# Burnley                     15
# Everton                     14
# Manchester United           14
# Southampton                 14
# West Ham United             13
# Aston Villa                 13
# Liverpool                   12
# Brentford                   12
# Brighton and Hove Albion    12
# Leeds United                12
# Leicester City              12
# Tottenham Hotspur           11
# Wolverhampton Wanderers     11
# Crystal Palace              11
# Manchester City             10
# Chelsea                     10
# Newcastle United             9
# Arsenal                      8
# Name: team, dtype: int64

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged[(merged["actual_x"] == 0 & merged["predicted_x"])]["team_x"].value_counts()
# Out:
# Watford                     18
# Burnley                     16
# Norwich City                16
# Everton                     15
# Leeds United                14
# Aston Villa                 14
# Southampton                 14
# Brighton and Hove Albion    13
# Leicester City              13
# Manchester United           13
# Wolverhampton Wanderers     12
# Brentford                   12
# Crystal Palace              12
# West Ham United             12
# Chelsea                      9
# Tottenham Hotspur            8
# Arsenal                      7
# Newcastle United             7
# Manchester City              5
# Liverpool                    3
# Name: team_x, dtype: int64

# %%
merged[(merged["team_x"] == "Tottenham Hotspur")]
# Out:
#      actual_x  predicted_x       date             team_x       opponent_x  \
# 310         1            1 2022-01-19  Tottenham Hotspur   Leicester City
# 311         0            1 2022-01-23  Tottenham Hotspur          Chelsea
# 312         0            1 2022-02-09  Tottenham Hotspur      Southampton
# 313         0            0 2022-02-13  Tottenham Hotspur           Wolves
# 314         1            0 2022-02-19  Tottenham Hotspur  Manchester City
# 315         0            0 2022-02-23  Tottenham Hotspur          Burnley
# 316         1            0 2022-02-26  Tottenham Hotspur     Leeds United
# 317         1            1 2022-03-07  Tottenham Hotspur          Everton
# 318         0            0 2022-03-12  Tottenham Hotspur   Manchester Utd
# 319         1            1 2022-03-16  Tottenham Hotspur         Brighton
# 320         1            0 2022-03-20  Tottenham Hotspur         West Ham
# 321         1            0 2022-04-03  Tottenham Hotspur    Newcastle Utd
# 322         1            1 2022-04-09  Tottenham Hotspur      Aston Villa
# 323         0            1 2022-04-16  Tottenham Hotspur         Brighton
# 324         0            0 2022-04-23  Tottenham Hotspur        Brentford
# 325         1            0 2022-05-01  Tottenham Hotspur   Leicester City
# 326         0            0 2022-05-07  Tottenham Hotspur        Liverpool
# 327         1            0 2022-05-12  Tottenham Hotspur          Arsenal
# 328         1            1 2022-05-15  Tottenham Hotspur          Burnley
# 329         1            1 2022-05-22  Tottenham Hotspur     Norwich City
#
#     result_x new_team_x  actual_y  predicted_y                    team_y  \
# 310        W  Tottenham         0            0            Leicester City
# 311        L  Tottenham         1            0                   Chelsea
# 312        L  Tottenham         1            0               Southampton
# 313        L  Tottenham         1            0   Wolverhampton Wanderers
# 314        W  Tottenham         0            1           Manchester City
# 315        L  Tottenham         1            0                   Burnley
# 316        W  Tottenham         0            0              Leeds United
# 317        W  Tottenham         0            0                   Everton
# 318        L  Tottenham         1            0         Manchester United
# 319        W  Tottenham         0            0  Brighton and Hove Albion
# 320        W  Tottenham         0            0           West Ham United
# 321        W  Tottenham         0            0          Newcastle United
# 322        W  Tottenham         0            0               Aston Villa
# 323        L  Tottenham         1            0  Brighton and Hove Albion
# 324        D  Tottenham         0            1                 Brentford
# 325        W  Tottenham         0            0            Leicester City
# 326        D  Tottenham         0            1                 Liverpool
# 327        W  Tottenham         0            0                   Arsenal
# 328        W  Tottenham         0            0                   Burnley
# 329        W  Tottenham         0            0              Norwich City
#
#     opponent_y result_y       new_team_y
# 310  Tottenham        L   Leicester City
# 311  Tottenham        W          Chelsea
# 312  Tottenham        W      Southampton
# 313  Tottenham        W           Wolves
# 314  Tottenham        L  Manchester City
# 315  Tottenham        W          Burnley
# 316  Tottenham        L     Leeds United
# 317  Tottenham        L          Everton
# 318  Tottenham        W   Manchester Utd
# 319  Tottenham        L         Brighton
# 320  Tottenham        L         West Ham
# 321  Tottenham        L    Newcastle Utd
# 322  Tottenham        L      Aston Villa
# 323  Tottenham        W         Brighton
# 324  Tottenham        D        Brentford
# 325  Tottenham        L   Leicester City
# 326  Tottenham        D        Liverpool
# 327  Tottenham        L          Arsenal
# 328  Tottenham        L          Burnley
# 329  Tottenham        L     Norwich City

# %%
merged["team_x"].unique()
# Out:
# array(['Arsenal', 'Aston Villa', 'Brentford', 'Brighton and Hove Albion',
#        'Burnley', 'Chelsea', 'Crystal Palace', 'Everton', 'Leeds United',
#        'Leicester City', 'Liverpool', 'Manchester City',
#        'Manchester United', 'Newcastle United', 'Norwich City',
#        'Southampton', 'Tottenham Hotspur', 'Watford', 'West Ham United',
#        'Wolverhampton Wanderers'], dtype=object)

# %%
19*20
# Out:
# 380

# %%
57/89
# Out:
# 0.6404494382022472

# %%
df = merged.groupby(['team_x']).count()

# %%
df
# Out:
#                           actual_x  predicted_x  date  opponent_x  result_x  \
# team_x
# Arsenal                         18           18    18          18        18
# Aston Villa                     20           20    20          20        20
# Brentford                       20           20    20          20        20
# Brighton and Hove Albion        20           20    20          20        20
# Burnley                         22           22    22          22        22
# Chelsea                         18           18    18          18        18
# Crystal Palace                  18           18    18          18        18
# Everton                         21           21    21          21        21
# Leeds United                    20           20    20          20        20
# Leicester City                  20           20    20          20        20
# Liverpool                       19           19    19          19        19
# Manchester City                 17           17    17          17        17
# Manchester United               20           20    20          20        20
# Newcastle United                19           19    19          19        19
# Norwich City                    19           19    19          19        19
# Southampton                     19           19    19          19        19
# Tottenham Hotspur               20           20    20          20        20
# Watford                         20           20    20          20        20
# West Ham United                 18           18    18          18        18
# Wolverhampton Wanderers         20           20    20          20        20
#
#                           new_team_x  actual_y  predicted_y  team_y  \
# team_x
# Arsenal                           18        18           18      18
# Aston Villa                       20        20           20      20
# Brentford                         20        20           20      20
# Brighton and Hove Albion          20        20           20      20
# Burnley                           22        22           22      22
# Chelsea                           18        18           18      18
# Crystal Palace                    18        18           18      18
# Everton                           21        21           21      21
# Leeds United                      20        20           20      20
# Leicester City                    20        20           20      20
# Liverpool                         19        19           19      19
# Manchester City                   17        17           17      17
# Manchester United                 20        20           20      20
# Newcastle United                  19        19           19      19
# Norwich City                      19        19           19      19
# Southampton                       19        19           19      19
# Tottenham Hotspur                 20        20           20      20
# Watford                           20        20           20      20
# West Ham United                   18        18           18      18
# Wolverhampton Wanderers           20        20           20      20
#
#                           opponent_y  result_y  new_team_y
# team_x
# Arsenal                           18        18          18
# Aston Villa                       20        20          20
# Brentford                         20        20          20
# Brighton and Hove Albion          20        20          20
# Burnley                           22        22          22
# Chelsea                           18        18          18
# Crystal Palace                    18        18          18
# Everton                           21        21          21
# Leeds United                      20        20          20
# Leicester City                    20        20          20
# Liverpool                         19        19          19
# Manchester City                   17        17          17
# Manchester United                 20        20          20
# Newcastle United                  19        19          19
# Norwich City                      19        19          19
# Southampton                       19        19          19
# Tottenham Hotspur                 20        20          20
# Watford                           20        20          20
# West Ham United                   18        18          18
# Wolverhampton Wanderers           20        20          20

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["team_x"].value_counts()
# Out:
# Liverpool                   11
# Manchester City             11
# Chelsea                      9
# Tottenham Hotspur            9
# Brentford                    4
# Arsenal                      3
# Aston Villa                  3
# Brighton and Hove Albion     3
# Manchester United            3
# Leeds United                 2
# Newcastle United             2
# Southampton                  2
# Burnley                      1
# Crystal Palace               1
# West Ham United              1
# Wolverhampton Wanderers      1
# Name: team_x, dtype: int64

# %%
merged[merged["team_x"] == "Manchester City"]
# Out:
#      actual_x  predicted_x       date           team_x      opponent_x  \
# 216         1            0 2022-01-15  Manchester City         Chelsea
# 217         0            0 2022-01-22  Manchester City     Southampton
# 218         1            0 2022-02-09  Manchester City       Brentford
# 219         1            1 2022-02-12  Manchester City    Norwich City
# 220         0            1 2022-02-19  Manchester City       Tottenham
# 221         1            0 2022-02-26  Manchester City         Everton
# 222         1            0 2022-03-06  Manchester City  Manchester Utd
# 223         0            1 2022-03-14  Manchester City  Crystal Palace
# 224         1            1 2022-04-02  Manchester City         Burnley
# 225         0            0 2022-04-10  Manchester City       Liverpool
# 226         1            1 2022-04-20  Manchester City        Brighton
# 227         1            1 2022-04-23  Manchester City         Watford
# 228         1            1 2022-04-30  Manchester City    Leeds United
# 229         1            1 2022-05-08  Manchester City   Newcastle Utd
# 230         1            1 2022-05-11  Manchester City          Wolves
# 231         0            1 2022-05-15  Manchester City        West Ham
# 232         1            1 2022-05-22  Manchester City     Aston Villa
#
#     result_x       new_team_x  actual_y  predicted_y  \
# 216        W  Manchester City         0            0
# 217        D  Manchester City         0            0
# 218        W  Manchester City         0            0
# 219        W  Manchester City         0            0
# 220        L  Manchester City         1            0
# 221        W  Manchester City         0            0
# 222        W  Manchester City         0            0
# 223        D  Manchester City         0            0
# 224        W  Manchester City         0            0
# 225        D  Manchester City         0            0
# 226        W  Manchester City         0            0
# 227        W  Manchester City         0            0
# 228        W  Manchester City         0            0
# 229        W  Manchester City         0            0
# 230        W  Manchester City         0            0
# 231        D  Manchester City         0            0
# 232        W  Manchester City         0            0
#
#                        team_y       opponent_y result_y      new_team_y
# 216                   Chelsea  Manchester City        L         Chelsea
# 217               Southampton  Manchester City        D     Southampton
# 218                 Brentford  Manchester City        L       Brentford
# 219              Norwich City  Manchester City        L    Norwich City
# 220         Tottenham Hotspur  Manchester City        W       Tottenham
# 221                   Everton  Manchester City        L         Everton
# 222         Manchester United  Manchester City        L  Manchester Utd
# 223            Crystal Palace  Manchester City        D  Crystal Palace
# 224                   Burnley  Manchester City        L         Burnley
# 225                 Liverpool  Manchester City        D       Liverpool
# 226  Brighton and Hove Albion  Manchester City        L        Brighton
# 227                   Watford  Manchester City        L         Watford
# 228              Leeds United  Manchester City        L    Leeds United
# 229          Newcastle United  Manchester City        L   Newcastle Utd
# 230   Wolverhampton Wanderers  Manchester City        L          Wolves
# 231           West Ham United  Manchester City        D        West Ham
# 232               Aston Villa  Manchester City        L     Aston Villa
